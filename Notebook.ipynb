# %%
import main

# %%
link = "https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json"
plot = main.Plot()
plot.draw_plots(link, 'Plots\\')
# Out:
# C:\Users\Lenovo\Desktop\pythonProject\main.py:13: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()
# hello
# ['Plots\\gt_corners_gt_corners.png',
#  'Plots\\gt_corners_rb_corners.png',
#  'Plots\\gt_corners_mean.png',
#  'Plots\\gt_corners_max.png',
#  'Plots\\gt_corners_min.png',
#  'Plots\\gt_corners_floor_mean.png',
#  'Plots\\gt_corners_floor_max.png',
#  'Plots\\gt_corners_floor_min.png',
#  'Plots\\gt_corners_ceiling_mean.png',
#  'Plots\\gt_corners_ceiling_max.png',
#  'Plots\\gt_corners_ceiling_min.png',
#  'Plots\\rb_corners_rb_corners.png',
#  'Plots\\rb_corners_mean.png',
#  'Plots\\rb_corners_max.png',
#  'Plots\\rb_corners_min.png',
#  'Plots\\rb_corners_floor_mean.png',
#  'Plots\\rb_corners_floor_max.png',
# ...
